# %% [markdown]
# # Generate snowflake schema and insert data into Netezza
# > 1. at first I will generate data on equity transactions using faker, random and list of dummy of companies / industries
# > 2. only 4 stocks correspond to real companies ('BAC', 'IBM', 'AMZN', 'HD') as they are used by the agent
# > 3. then I will create corresponding Netezza tables, save files as csvs and insert data from local files to Netezza
#
# ![200](attachment:image.png)

# %%
import os
import pandas as pd
import random
from faker import Faker
from datetime import datetime, timedelta

from dotenv import load_dotenv
import nzpy

fake = Faker('en_US')
random.seed(42)
load_dotenv('.env_load')
# Out:
# True

# %% [markdown]
# ## Settings

# %%
# to get number of accounts
accounts_df = pd.read_csv('../Data-Preparation/gen_data/accounts.csv')
accounts_df.describe()
# Out:
#           account_id    customer_id
# count  246301.000000  246301.000000
# mean   123151.000000   61469.608175
# std     71101.118663   35515.129664
# min         1.000000       1.000000
# 25%     61576.000000   30718.000000
# 50%    123151.000000   61498.000000
# 75%    184726.000000   92187.000000
# max    246301.000000  123000.000000

# %%
# Date range for time dimension
start_date = datetime(2019, 1, 1)
end_date = datetime(2025, 3, 31)

NUM_FCOMPANIES = 100
NUM_TRANSACTIONS = 1200000  # Number of transactions
NUM_ACCOUNTS = len(accounts_df) # Number of trading accounts

# %%
def df_overview(df):
    display(df.head())
    display(df.info())
    display(df.describe())

# %% [markdown]
# ### Expected directories for temp files and logs for Netezza

# %%
dir_logs = './logs'
dir_nz = './tmp_nz'
# Create the directory if it doesn't exist
os.makedirs(dir_logs, exist_ok=True)
os.makedirs(dir_nz, exist_ok=True)

# %% [markdown]
# ## Data Generation

# %% [markdown]
# ### Stocks dimension

# %%
def generate_ticker(name):
    """Create a stock ticker symbol from the company name."""
    words = name.split()
    if len(words) == 1:
        return name[:4].upper()
    return (words[0][:2] + words[-1][:2]).upper()

# %%
# Real companies
REAL_STOCKS = [
    ('BAC', 'Bank of America', 'Financials', 'Banking'),
    ('IBM', 'IBM', 'Technology', 'IT Services'),
    ('AMZN', 'Amazon', 'Consumer Discretionary', 'E-Commerce'),
    ('HD', 'Home Depot', 'Consumer Discretionary', 'Home Improvement')
]

SECTORS_IND = list(zip(['Technology', 'Technology', 'Energy', 'Technology', 'Industrial',
         'Healthcare', 'Consumer Discretionary', 'Financials', 'Technology', 'Consumer Discretionary',
         'Technology', 'Energy', 'AI & Machine Learning', 'Healthcare',
         'Technology', 'Healthcare', 'Financials', 'Consumer Discretionary',
         'Technology', 'Cloud Computing', 'Energy', 'Aerospace', 'AI & Robotics',
         'Cybersecurity', 'Neuroscience', 'Biotechnology', 'Computing Hardware',
         'Augmented Reality', 'Cybersecurity', 'Digital Media', 'Aviation',
         'AI Research', 'Renewable Energy', 'Blockchain', 'Telecommunications',
         'Data Analytics', 'Automotive', 'Digital Services', 'Aerospace Engineering',
         'Automation'],
        ['AI Solutions', 'Quantum Computing', 'Renewable Energy', 'Cybersecurity',
         'Aerospace Engineering', 'Biotechnology', 'Electric Vehicles', 'Investment Banking',
         'Digital Advertising', 'E-Commerce', 'Robotics', 'Solar Energy',
         'Deep Learning Systems', 'Genomics', 'Satellite Communications',
         'Medical Devices', 'Wealth Management', 'Automobile Manufacturing',
         'Supercomputers', 'Cloud Services', 'Green Energy', 'Space Exploration',
         'Machine Learning', 'Network Security', 'Brain-Computer Interfaces',
         'DNA Editing', 'High-Performance Computing', 'Mixed Reality',
         'Advanced Cybersecurity', 'Streaming Media', 'Commercial Aviation',
         'AI Research', 'Solar Technology', 'Cryptocurrency', '5G Networks',
         'Big Data Analytics', 'Autonomous Vehicles', 'E-Commerce Platforms',
         'Interplanetary Travel', 'Industrial Automation']))

# Generate 40 fake companies dynamically
FAKE_COMPANY_NAMES = [fake.company() for _ in range(NUM_FCOMPANIES)]
SECTOR, INDUSTRY = zip(*[random.choice(SECTORS_IND) for _ in range(NUM_FCOMPANIES)])

# %%
FAKE_STOCKS = [
    (generate_ticker(name), name, sector, industry)
    for name, sector, industry in zip(
        FAKE_COMPANY_NAMES, SECTOR, INDUSTRY

    )
]

# %%
# Combine real and fake stocks
STOCKS = REAL_STOCKS + FAKE_STOCKS

# Generate dim_stock table
dim_stock = pd.DataFrame({
    'stock_id': range(1, len(STOCKS) + 1),
    'stock_symbol': [s[0] for s in STOCKS],
    'stock_name': [s[1] for s in STOCKS],
    'sector': [s[2] for s in STOCKS],
    'industry': [s[3] for s in STOCKS],
    'market_cap': [random.randint(100, 500) * 1e9 for _ in STOCKS]  # Market cap in billions
})

# %%
df_overview(dim_stock)
# Out:
#    stock_id stock_symbol       stock_name                  sector  \
# 0         1          BAC  Bank of America              Financials
# 1         2          IBM              IBM              Technology
# 2         3         AMZN           Amazon  Consumer Discretionary
# 3         4           HD       Home Depot  Consumer Discretionary
# 4         5         SMIT     Smith-Watson              Financials
#
#              industry    market_cap
# 0             Banking  2.260000e+11
# 1         IT Services  4.810000e+11
# 2          E-Commerce  3.870000e+11
# 3    Home Improvement  3.750000e+11
# 4  Investment Banking  2.340000e+11
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   stock_id      104 non-null    int64
#  1   stock_symbol  104 non-null    object
#  2   stock_name    104 non-null    object
#  3   sector        104 non-null    object
#  4   industry      104 non-null    object
#  5   market_cap    104 non-null    float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 5.0+ KB
# None
#          stock_id    market_cap
# count  104.000000  1.040000e+02
# mean    52.500000  3.105000e+11
# std     30.166206  1.202521e+11
# min      1.000000  1.000000e+11
# 25%     26.750000  1.985000e+11
# 50%     52.500000  3.270000e+11
# 75%     78.250000  4.052500e+11
# max    104.000000  4.980000e+11

# %% [markdown]
# ### Date dimension

# %%
date_range = pd.date_range(start=start_date, end=end_date)
dim_date = pd.DataFrame({
    'date_id': range(1, len(date_range) + 1),
    'transaction_date': date_range,
    'year': date_range.year,
    'quarter': date_range.quarter,
    'month': date_range.month,
    'week': date_range.isocalendar().week,
    'day_of_week': date_range.dayofweek,
    'is_weekend': date_range.dayofweek >= 5
})

# %%
dim_date['is_weekend'] = dim_date['is_weekend'].map({True: 1, False: 0})

# %%
df_overview(dim_date)
# Out:
#             date_id transaction_date  year  quarter  month  week  day_of_week  \
# 2019-01-01        1       2019-01-01  2019        1      1     1            1
# 2019-01-02        2       2019-01-02  2019        1      1     1            2
# 2019-01-03        3       2019-01-03  2019        1      1     1            3
# 2019-01-04        4       2019-01-04  2019        1      1     1            4
# 2019-01-05        5       2019-01-05  2019        1      1     1            5
#
#             is_weekend
# 2019-01-01           0
# 2019-01-02           0
# 2019-01-03           0
# 2019-01-04           0
# 2019-01-05           1
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2282 entries, 2019-01-01 to 2025-03-31
# Freq: D
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date_id           2282 non-null   int64
#  1   transaction_date  2282 non-null   datetime64[ns]
#  2   year              2282 non-null   int32
#  3   quarter           2282 non-null   int32
#  4   month             2282 non-null   int32
#  5   week              2282 non-null   UInt32
#  6   day_of_week       2282 non-null   int32
#  7   is_weekend        2282 non-null   int64
# dtypes: UInt32(1), datetime64[ns](1), int32(4), int64(2)
# memory usage: 118.1 KB
# None
#            date_id     transaction_date         year      quarter  \
# count  2282.000000                 2282  2282.000000  2282.000000
# mean   1141.500000  2022-02-14 12:00:00  2021.638475     2.448729
# min       1.000000  2019-01-01 00:00:00  2019.000000     1.000000
# 25%     571.250000  2020-07-24 06:00:00  2020.000000     1.000000
# 50%    1141.500000  2022-02-14 12:00:00  2022.000000     2.000000
# 75%    1711.750000  2023-09-07 18:00:00  2023.000000     3.000000
# max    2282.000000  2025-03-31 00:00:00  2025.000000     4.000000
# std     658.900979                  NaN     1.807814     1.133852
#
#              month       week  day_of_week   is_weekend
# count  2282.000000     2282.0  2282.000000  2282.000000
# mean      6.343558  25.809378     3.000000     0.285714
# min       1.000000        1.0     0.000000     0.000000
# 25%       3.000000       12.0     1.000000     0.000000
# 50%       6.000000       25.5     3.000000     0.000000
# 75%       9.000000       39.0     5.000000     1.000000
# max      12.000000       53.0     6.000000     1.000000
# std       3.497644  15.259786     2.000438     0.451853

# %% [markdown]
# ### Exchanges dimension

# %%
# Generate dim_exchange table with 4 exchanges (2 real, 2 fake)
EXCHANGES = [
    ('NYSE', 'USA', 'EST', 'USD'),
    ('NASDAQ', 'USA', 'EST', 'USD'),
    ('Global Digital Exchange', 'UK', 'GMT', 'GBP'),
    ('FutureTech Exchange', 'Singapore', 'SGT', 'SGD')
]

dim_exchange = pd.DataFrame({
    'exchange_id': range(1, len(EXCHANGES) + 1),
    'exchange_name': [e[0] for e in EXCHANGES],
    'country': [e[1] for e in EXCHANGES],
    'timezone': [e[2] for e in EXCHANGES],
    'currency': [e[3] for e in EXCHANGES]
})

# %%
df_overview(dim_exchange)
# Out:
#    exchange_id            exchange_name    country timezone currency
# 0            1                     NYSE        USA      EST      USD
# 1            2                   NASDAQ        USA      EST      USD
# 2            3  Global Digital Exchange         UK      GMT      GBP
# 3            4      FutureTech Exchange  Singapore      SGT      SGD
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   exchange_id    4 non-null      int64
#  1   exchange_name  4 non-null      object
#  2   country        4 non-null      object
#  3   timezone       4 non-null      object
#  4   currency       4 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 292.0+ bytes
# None
#        exchange_id
# count     4.000000
# mean      2.500000
# std       1.290994
# min       1.000000
# 25%       1.750000
# 50%       2.500000
# 75%       3.250000
# max       4.000000

# %% [markdown]
# ### Accounts dimensions

# %%
dim_account = pd.DataFrame({
    'account_id': range(1, NUM_ACCOUNTS + 1),
    'account_type': random.choices(['Retail', 'Institutional', 'Margin'], k=NUM_ACCOUNTS),
    'status': random.choices(['Active', 'Suspended', 'Closed'], k=NUM_ACCOUNTS),
    'opening_date': [fake.date_between(start_date='-5y', end_date='today') for _ in range(NUM_ACCOUNTS)],
    'risk_level': random.choices(['Low', 'Medium', 'High'], k=NUM_ACCOUNTS),
    'balance': [round(random.uniform(1000, 1000000), 2) for _ in range(NUM_ACCOUNTS)],
    'margin_enabled': random.choices([True, False], k=NUM_ACCOUNTS),
    'trading_experience': random.choices(['Beginner', 'Intermediate', 'Expert'], k=NUM_ACCOUNTS)
})

# %%
dim_account['margin_enabled'] = dim_account['margin_enabled'].map({True: 1, False: 0})

# %%
df_overview(dim_account)
# Out:
#    account_id   account_type  status opening_date risk_level    balance  \
# 0           1         Margin  Active   2024-07-09     Medium  485566.23
# 1           2         Retail  Closed   2023-05-06        Low  353539.14
# 2           3         Retail  Active   2023-03-27       High  133422.66
# 3           4         Margin  Active   2024-05-21     Medium  349185.89
# 4           5  Institutional  Active   2022-09-19       High  970433.96
#
#    margin_enabled trading_experience
# 0               1           Beginner
# 1               1             Expert
# 2               1       Intermediate
# 3               1           Beginner
# 4               1             Expert
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246301 entries, 0 to 246300
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   account_id          246301 non-null  int64
#  1   account_type        246301 non-null  object
#  2   status              246301 non-null  object
#  3   opening_date        246301 non-null  object
#  4   risk_level          246301 non-null  object
#  5   balance             246301 non-null  float64
#  6   margin_enabled      246301 non-null  int64
#  7   trading_experience  246301 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 15.0+ MB
# None
#           account_id        balance  margin_enabled
# count  246301.000000  246301.000000   246301.000000
# mean   123151.000000  500499.436306        0.499430
# std     71101.118663  288129.090973        0.500001
# min         1.000000    1000.500000        0.000000
# 25%     61576.000000  251729.770000        0.000000
# 50%    123151.000000  501188.710000        0.000000
# 75%    184726.000000  749627.700000        1.000000
# max    246301.000000  999998.930000        1.000000

# %%
dim_account.to_csv("accounts_info.csv", index=False)

# %% [markdown]
# ### Transactions table

# %%
# Generate fact_transactions
fact_transactions = pd.DataFrame({
    'transaction_id': range(1, NUM_TRANSACTIONS + 1),
    'account_id': random.choices(dim_account['account_id'], k=NUM_TRANSACTIONS),
    'stock_id': random.choices(dim_stock['stock_id'], k=NUM_TRANSACTIONS),
    'date_id': random.choices(dim_date['date_id'], k=NUM_TRANSACTIONS),
    'exchange_id': random.choices(dim_exchange['exchange_id'], k=NUM_TRANSACTIONS),
    'order_type': random.choices(['Buy', 'Sell'], k=NUM_TRANSACTIONS),
    'quantity': [random.randint(1, 1000) for _ in range(NUM_TRANSACTIONS)],
    'price': [round(random.uniform(50, 5000), 2) for _ in range(NUM_TRANSACTIONS)],  # Simulated price
})

# Calculate total value
fact_transactions['total_value'] = (fact_transactions['quantity'] * fact_transactions['price']).round(2)
# Out:
# /opt/homebrew/Cellar/python@3.13/3.13.2/Frameworks/Python.framework/Versions/3.13/lib/python3.13/random.py:471: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return [population[floor(random() * n)] for i in _repeat(None, k)]

# %%
df_overview(fact_transactions)
# Out:
#    transaction_id  account_id  stock_id  date_id  exchange_id order_type  \
# 0               1      244583        13      358            2        Buy
# 1               2       34657        98     1496            3        Buy
# 2               3       53095        61      139            4        Buy
# 3               4      145621       100      957            1       Sell
# 4               5      171953        21     1260            3        Buy
#
#    quantity    price  total_value
# 0       405  1919.91    777563.55
# 1       746   536.50    400229.00
# 2       685  2741.36   1877831.60
# 3       924  4661.20   4306948.80
# 4       467  3585.97   1674647.99
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200000 entries, 0 to 1199999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   transaction_id  1200000 non-null  int64
#  1   account_id      1200000 non-null  int64
#  2   stock_id        1200000 non-null  int64
#  3   date_id         1200000 non-null  int64
#  4   exchange_id     1200000 non-null  int64
#  5   order_type      1200000 non-null  object
#  6   quantity        1200000 non-null  int64
#  7   price           1200000 non-null  float64
#  8   total_value     1200000 non-null  float64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 82.4+ MB
# None
#        transaction_id    account_id      stock_id       date_id   exchange_id  \
# count    1.200000e+06  1.200000e+06  1.200000e+06  1.200000e+06  1.200000e+06
# mean     6.000005e+05  1.230865e+05  5.247688e+01  1.141846e+03  2.500114e+00
# std      3.464103e+05  7.115345e+04  3.000408e+01  6.587891e+02  1.118213e+00
# min      1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%      3.000008e+05  6.144800e+04  2.700000e+01  5.710000e+02  1.000000e+00
# 50%      6.000005e+05  1.230940e+05  5.200000e+01  1.142000e+03  3.000000e+00
# 75%      9.000002e+05  1.847432e+05  7.800000e+01  1.712000e+03  4.000000e+00
# max      1.200000e+06  2.463010e+05  1.040000e+02  2.282000e+03  4.000000e+00
#
#            quantity         price   total_value
# count  1.200000e+06  1.200000e+06  1.200000e+06
# mean   5.004701e+02  2.527942e+03  1.265075e+06
# std    2.886576e+02  1.428278e+03  1.101838e+06
# min    1.000000e+00  5.001000e+01  5.720000e+01
# 25%    2.500000e+02  1.291110e+03  3.537224e+05
# 50%    5.000000e+02  2.529190e+03  9.508456e+05
# 75%    7.510000e+02  3.764240e+03  1.929987e+06
# max    1.000000e+03  4.999990e+03  4.993040e+06

# %% [markdown]
# ## Save all generated data to local directory

# %%
generated_dfs_dict = {
    'dim_date': dim_date,
    'dim_account': dim_account,
    'dim_exchange': dim_exchange,
    'dim_stock': dim_stock,
    'fact_transactions': fact_transactions,
}

# %%
for file_name, df in generated_dfs_dict.items():
    df.to_csv(f'{dir_nz}/{file_name}.csv', index=False, sep="|")

# %% [markdown]
# ## Data upload into Netezza

# %% [markdown]
# ### Connection

# %%
# Define connection parameters
hostname = os.getenv('hostname')
port = int(os.getenv('port'))
database = os.getenv('database')
username = os.getenv('username')
password = os.getenv('password')
schema_name = os.getenv('schema')

# Connection string (no need for ODBC)
connection_string = f'jdbc:netezza://{hostname}:{port}/{database}'

# %%
# Create a connection to Netezza
try:
    conn = nzpy.connect(
        host=hostname,
        port=port,
        user=username,
        password=password,
        database=database
    )
    print("Connected to Netezza!")

    # Create a cursor to execute queries
    cursor = conn.cursor()

    # Example: List all tables in the database
    cursor.execute("SELECT schema, tablename FROM _v_table;")
    rows = cursor.fetchall()

    print("List of tables in the database:")
    for row in rows:
        print(f'{row[0]}.{row[1]}')

except Exception as e:
    print(f"Error: {e}")
# Out:
# Connected to Netezza!
# List of tables in the database:
# DEFINITION_SCHEMA._T_OBJECT
# DEFINITION_SCHEMA._T_OBJECT_CLASSES
# DEFINITION_SCHEMA._T_PROC
# DEFINITION_SCHEMA._T_TYPE
# DEFINITION_SCHEMA._T_ATTRIBUTE
# DEFINITION_SCHEMA._T_CLASS
# DEFINITION_SCHEMA._T_RELCHECK
# DEFINITION_SCHEMA._T_ATTRDEF
# DEFINITION_SCHEMA._T_TRIGGER
# DEFINITION_SCHEMA._T_INHERITS
# DEFINITION_SCHEMA._T_INDEX
# DEFINITION_SCHEMA._T_STATISTIC
# DEFINITION_SCHEMA._T_OPERATOR
# DEFINITION_SCHEMA._T_OPCLASS
# DEFINITION_SCHEMA._T_AM
# DEFINITION_SCHEMA._T_AMOP
# DEFINITION_SCHEMA._T_AMPROC
# DEFINITION_SCHEMA._T_LANGUAGE
# DEFINITION_SCHEMA._T_LARGEOBJECT
# DEFINITION_SCHEMA._T_AGGREGATE
# DEFINITION_SCHEMA._T_IPL
# DEFINITION_SCHEMA._T_INHERITPROC
# DEFINITION_SCHEMA._T_REWRITE
# DEFINITION_SCHEMA._T_VIEW_USERSQL
# DEFINITION_SCHEMA._T_LISTENER
# DEFINITION_SCHEMA._T_DESCRIPTION
# DEFINITION_SCHEMA._T_DIST_MAP
# DEFINITION_SCHEMA._T_ORGANIZE_ON
# DEFINITION_SCHEMA._T_GROOM_HISTORY
# DEFINITION_SCHEMA._T_THIN
# DEFINITION_SCHEMA._T_ALTBASE
# DEFINITION_SCHEMA._T_SELCACHE
# DEFINITION_SCHEMA._T_EXTERNAL
# DEFINITION_SCHEMA._T_EXTOBJECT
# DEFINITION_SCHEMA._T_EXTTABALLOW
# DEFINITION_SCHEMA._T_EXTZONES
# DEFINITION_SCHEMA._T_CONSTRAINT
# DEFINITION_SCHEMA._T_CONST_RELATTR
# DEFINITION_SCHEMA._T_CONST_REFATTR
# DEFINITION_SCHEMA._T_SYNONYM
# DEFINITION_SCHEMA._T_BACKUP_GROUP
# DEFINITION_SCHEMA._T_BACKUP_GROUP_MEMBER
# DEFINITION_SCHEMA._T_RESTORE_ATTRESTOID
# DEFINITION_SCHEMA._T_LIBRARY
# DEFINITION_SCHEMA._T_UDXATTRIBUTE
# DEFINITION_SCHEMA._T_UDXENVIRONMENT
# DEFINITION_SCHEMA._T_SCHEMA
# DEFINITION_SCHEMA._T_DATABASE
# DEFINITION_SCHEMA._T_VARIABLE
# DEFINITION_SCHEMA._T_USER
# DEFINITION_SCHEMA._T_GROUP
# DEFINITION_SCHEMA._T_ROLE
# DEFINITION_SCHEMA._T_LOG
# DEFINITION_SCHEMA._T_ENV
# DEFINITION_SCHEMA._T_GRPOBJ_PRIV
# DEFINITION_SCHEMA._T_USROBJ_PRIV
# DEFINITION_SCHEMA._T_GRPUSR
# DEFINITION_SCHEMA._T_SEC_OBJ
# DEFINITION_SCHEMA._T_ACL
# DEFINITION_SCHEMA._T_ODBC_FEATURE
# DEFINITION_SCHEMA._T_OLEDB_FEATURE
# DEFINITION_SCHEMA._T_JDBC_FEATURE
# DEFINITION_SCHEMA._T_DOTNET_FEATURE
# DEFINITION_SCHEMA._T_ERROR_MSG
# DEFINITION_SCHEMA._T_REPL_NODE
# DEFINITION_SCHEMA._T_REPL_SET
# DEFINITION_SCHEMA._T_REPL_SET_NODE
# DEFINITION_SCHEMA._T_REPL_DATABASE
# DEFINITION_SCHEMA._T_BNR_REPL_DATABASE
# DEFINITION_SCHEMA._T_REPL_STATE
# DEFINITION_SCHEMA._T_REPL_MAX_CSN
# DEFINITION_SCHEMA._T_TMP_REPL_NODE
# DEFINITION_SCHEMA._T_TMP_REPL_SET
# DEFINITION_SCHEMA._T_TMP_REPL_SET_NODE
# DEFINITION_SCHEMA._T_TMP_REPL_STATE
# DEFINITION_SCHEMA._T_REPL_COMMIT_LOG
# DEFINITION_SCHEMA._T_REPL_COMMIT_CAPTURED
# DEFINITION_SCHEMA._T_REPL_EXTERNAL_FILE
# DEFINITION_SCHEMA._T_REPL_ROLE_TEXT
# DEFINITION_SCHEMA._T_REPL_STATE_TEXT
# DEFINITION_SCHEMA._T_REPL_DBSTATE_TEXT
# DEFINITION_SCHEMA._T_REPL_APPLY_LOG
# DEFINITION_SCHEMA._T_REPL_QUEUE_LENGTH
# DEFINITION_SCHEMA._T_REPL_CAPTURE_DBACCESS
# DEFINITION_SCHEMA._T_REPL_PTS_UTILIZATION
# DEFINITION_SCHEMA._T_REPL_APPLY_DBACCESS
# DEFINITION_SCHEMA._T_REPL_TX_FORK
# DEFINITION_SCHEMA._T_REPL_APPLY_DATAFILE_LOG
# DEFINITION_SCHEMA._T_REPL_CAPTURE_TABLEACCESS
# DEFINITION_SCHEMA._T_REPL_CAPTURE_INVIS
# DEFINITION_SCHEMA._T_REPL_APPLY_MAP
# DEFINITION_SCHEMA._T_REPL_DBOS_NEXT_XID
# DEFINITION_SCHEMA._T_REPL_APPLY_INVIS
# DEFINITION_SCHEMA._T_REPL_CAPTURE_BY_VALUE_LOAD
# DEFINITION_SCHEMA._T_REPL_CAPTURE_SEQUENCE
# DEFINITION_SCHEMA._T_REPL_CAPTURE_EXTRA
# DEFINITION_SCHEMA._T_REPL_APPLY_EXTRA
# DEFINITION_SCHEMA._T_REPL_SET_NODE_V1
# DEFINITION_SCHEMA._T_TMP_REPL_SET_NODE_V1
# DEFINITION_SCHEMA._T_REPL_RECOVERY_STATE
# DEFINITION_SCHEMA._T_REPL_RECOVERY_STATE_TEXT
# DEFINITION_SCHEMA._T_REPL_SET_STATE
# DEFINITION_SCHEMA._T_REPL_NODE_STATE
# DEFINITION_SCHEMA._T_QUERYSTATUS
# DEFINITION_SCHEMA._T_PLANSTATUS
# DEFINITION_SCHEMA._T_GROOM_STATUS
# DEFINITION_SCHEMA._T_GROOM_MODE
# DEFINITION_SCHEMA._T_PG_LOCKS
# DEFINITION_SCHEMA._T_SESSCTX
# DEFINITION_SCHEMA._T_PGTX
# DEFINITION_SCHEMA._T_SESSION_VAR
# DEFINITION_SCHEMA._T_DSLICE
# DEFINITION_SCHEMA._T_HWCOMP
# DEFINITION_SCHEMA._T_HWEVENT
# DEFINITION_SCHEMA._T_EVENT_INFO
# DEFINITION_SCHEMA._T_HWTYPETEXT
# DEFINITION_SCHEMA._T_HWROLETEXT
# DEFINITION_SCHEMA._T_HWSTATETEXT
# DEFINITION_SCHEMA._T_SPUPARTITIONTYPETEXT
# DEFINITION_SCHEMA._T_SPUPARTITION
# DEFINITION_SCHEMA._T_LOGICALPARTITION
# DEFINITION_SCHEMA._T_LUN
# DEFINITION_SCHEMA._T_SPUDEVICEMAP
# DEFINITION_SCHEMA._T_SCSI_PFE
# DEFINITION_SCHEMA._T_SCSI_ERRORS
# DEFINITION_SCHEMA._T_ECCERR
# DEFINITION_SCHEMA._T_DFPGAERR
# DEFINITION_SCHEMA._T_HWFAILED
# DEFINITION_SCHEMA._T_EVRULE
# DEFINITION_SCHEMA._T_EVTEMPLATE
# DEFINITION_SCHEMA._T_ENVIRON
# DEFINITION_SCHEMA._T_NBCONNECTOR
# DEFINITION_SCHEMA._T_SYSTEM_INFO
# DEFINITION_SCHEMA._T_SPACOMP
# DEFINITION_SCHEMA._T_HWTRANSITINFO
# DEFINITION_SCHEMA._T_SPUPARTTRANSITINFO
# DEFINITION_SCHEMA._T_LOGPARTTRANSITINFO
# DEFINITION_SCHEMA._T_ETHSWSTATS
# DEFINITION_SCHEMA._T_ETHSWPORTSTATS
# DEFINITION_SCHEMA._T_ETHSWMNMTPORTSTATS
# DEFINITION_SCHEMA._T_PHYSTATS
# DEFINITION_SCHEMA._T_FANSTATS
# DEFINITION_SCHEMA._T_BLOWERSTATS
# DEFINITION_SCHEMA._T_EVENTPROXYWAITING
# DEFINITION_SCHEMA._T_EVENTPROXYREPORTED
# DEFINITION_SCHEMA._T_HOSTRESOURCEINFO
# DEFINITION_SCHEMA._T_HOSTETHSTATS
# DEFINITION_SCHEMA._T_HOSTDRBDSTATS
# DEFINITION_SCHEMA._T_HOSTCPUCORESTATS
# DEFINITION_SCHEMA._T_HOSTFSSTATS
# DEFINITION_SCHEMA._T_HOSTCRMNODESTATS
# DEFINITION_SCHEMA._T_HOSTMEMORYSTATS
# DEFINITION_SCHEMA._T_HOSTDISKSTATS
# DEFINITION_SCHEMA._T_HOSTSASSTATS
# DEFINITION_SCHEMA._T_HOSTPWRSTATS
# DEFINITION_SCHEMA._T_HOSTIMMSTATS
# DEFINITION_SCHEMA._T_HWMON
# DEFINITION_SCHEMA._T_QRYSTAT
# DEFINITION_SCHEMA._T_QRYHIST
# DEFINITION_SCHEMA._T_V_TABLE
# DEFINITION_SCHEMA._T_V_VIEW
# DEFINITION_SCHEMA._T_V_SPMVIEW
# DEFINITION_SCHEMA._T_V_MATTHRESHOLD
# DEFINITION_SCHEMA._T_VT_NZREV
# DEFINITION_SCHEMA._T_VT_PG_TIME_OFFSET
# DEFINITION_SCHEMA._T_VT_SCHED_GRA
# DEFINITION_SCHEMA._T_VT_SCHED_SN
# DEFINITION_SCHEMA._T_VT_SCHED_SYS
# DEFINITION_SCHEMA._T_VT_SYSTEM_UTIL
# DEFINITION_SCHEMA._T_VT_PLAN_RESOURCE
# DEFINITION_SCHEMA._T_HIST_CONFIG
# DEFINITION_SCHEMA._T_SHOW_COHORT_HIERARCHY
# DEFINITION_SCHEMA._T_USER_SECURITY
# DEFINITION_SCHEMA._T_CRYPTO_KEYSTORE
# DEFINITION_SCHEMA._T_CRYPTO_KEY
# DEFINITION_SCHEMA._T_DFPGAERR_XS
# DEFINITION_SCHEMA._T_SYS_IDLE
# DEFINITION_SCHEMA._T_VECTOR_IDX
# DEFINITION_SCHEMA._T_CLIENT_COMPATIBILITY
# DEFINITION_SCHEMA._T_MD_REGEN_ERRORS
# DEFINITION_SCHEMA._T_SYS_DATATYPE
# DEFINITION_SCHEMA._T_VIRTUAL
# DEFINITION_SCHEMA._T_SYSTEMDEF
# DEFINITION_SCHEMA._T_KMIP_MAPPING
# DEFINITION_SCHEMA._T_CONNECTION
# DEFINITION_SCHEMA._T_PRIORITY
# DEFINITION_SCHEMA._T_CHARSET
# DEFINITION_SCHEMA._T_COLLATION
# DEFINITION_SCHEMA._T_TEMP_TABLE_INFO
# DEFINITION_SCHEMA._T_TEMP_TABLE_DTL
# DEFINITION_SCHEMA._T_TEMP_TABLE_ATTR
# DEFINITION_SCHEMA._T_TEMP_TABLE
# DEFINITION_SCHEMA._T_VREL
# DEFINITION_SCHEMA._T_BACKUP_HISTORY
# DEFINITION_SCHEMA._T_RESTORE_HISTORY
# DEFINITION_SCHEMA._T_BACKUP_TXLIST
# DEFINITION_SCHEMA._T_BACKUP_TABLE_HISTORY
# DEFINITION_SCHEMA._T_BACKUP_GROUP_HISTORY
# DEFINITION_SCHEMA._T_BACKUP_REPLINFO
# DEFINITION_SCHEMA._T_RESTORE_REPLINFO
# DEFINITION_SCHEMA._T_BACKUP_DIRINFO
# DEFINITION_SCHEMA._T_DEPEND
# DEFINITION_SCHEMA._T_PASSWORD_HISTORY
# DEFINITION_SCHEMA._T_AUTOMAINT_HISTORY
# DEFINITION_SCHEMA._T_SECURITY_LEVEL
# DEFINITION_SCHEMA._T_SECURITY_COHORT
# DEFINITION_SCHEMA._T_SECURITY_CATEGORY
# DEFINITION_SCHEMA._T_MLS_TABLE
# DEFINITION_SCHEMA._T_SECURITY_USER_COHORT
# DEFINITION_SCHEMA._T_SECURITY_USER_CATEGORY
# DEFINITION_SCHEMA._T_SECURITY_COHORT_HIERARCHY
# DEFINITION_SCHEMA._T_ACCESS_TIME
# DEFINITION_SCHEMA._T_SCHED_RULE
# DEFINITION_SCHEMA._T_SCHED_RULE_ATTR
# DEFINITION_SCHEMA._T_SCHED_RULE_ATTR_VAL
# DEFINITION_SCHEMA._T_EXTERNAL_DATA_SOURCE
# DEFINITION_SCHEMA._VT_BASIC_DEMO
# DEFINITION_SCHEMA._VT_DUAL
# DEFINITION_SCHEMA._VT_DUAL_DSLICE
# DEFINITION_SCHEMA._VT_SPU_TABLE_INFO
# DEFINITION_SCHEMA._VT_MEMORY_USAGE
# DEFINITION_SCHEMA._VT_MEMORY_ALL
# DEFINITION_SCHEMA._VT_MEMORY_NEW
# DEFINITION_SCHEMA._VT_TBLDICT
# DEFINITION_SCHEMA._VT_DISK_LOG
# DEFINITION_SCHEMA._VT_FPGA_LOG
# DEFINITION_SCHEMA._VT_DBOS_CONNECTION
# DEFINITION_SCHEMA._VT_OSINTER_EVENT
# DEFINITION_SCHEMA._VT_OSINTER_CMD
# DEFINITION_SCHEMA._VT_OSINTER_PLAN
# DEFINITION_SCHEMA._VT_OSINTER_TXID
# DEFINITION_SCHEMA._VT_SNIPPET_HISTORY
# DEFINITION_SCHEMA._VT_SCHED_EVENT
# DEFINITION_SCHEMA._VT_SCHED_WORK_QUEUE
# DEFINITION_SCHEMA._VT_SCHED_SN
# DEFINITION_SCHEMA._VT_SCHED_GRA
# DEFINITION_SCHEMA._VT_SYSTEM_UTIL
# DEFINITION_SCHEMA._VT_PLAN_RESOURCE
# DEFINITION_SCHEMA._VT_SCHED_SYS
# DEFINITION_SCHEMA._VT_SCHED_WORK_ITEM
# DEFINITION_SCHEMA._VT_SCHED_ID
# DEFINITION_SCHEMA._VT_OSINTER_ID
# DEFINITION_SCHEMA._VT_CURRENT_TIME
# DEFINITION_SCHEMA._VT_PLAN_LOG
# DEFINITION_SCHEMA._VT_DISK_SMARTATTR
# DEFINITION_SCHEMA._VT_SCSI_LOG_SENSE
# DEFINITION_SCHEMA._VT_SCSI_LOG_SENSE_RAW
# DEFINITION_SCHEMA._VT_SCSI_REQUEST_SENSE
# DEFINITION_SCHEMA._VT_SCSI_DEFECTS
# DEFINITION_SCHEMA._VT_PLAN_NODE
# DEFINITION_SCHEMA._VT_PLAN_SCAN
# DEFINITION_SCHEMA._VT_PLAN_RETURN
# DEFINITION_SCHEMA._VT_PLAN_HASH
# DEFINITION_SCHEMA._VT_PLAN_RESTRICT
# DEFINITION_SCHEMA._VT_PLAN_PROJECT
# DEFINITION_SCHEMA._VT_PLAN_SORT
# DEFINITION_SCHEMA._VT_PLAN_HASHJOIN
# DEFINITION_SCHEMA._VT_PLAN_AGGREGATE
# DEFINITION_SCHEMA._VT_PLAN_DOWNLOADTABLE
# DEFINITION_SCHEMA._VT_PLAN_SAVETEMP
# DEFINITION_SCHEMA._VT_PLAN_DONE
# DEFINITION_SCHEMA._VT_PLAN_EXISTSJOIN
# DEFINITION_SCHEMA._VT_SPU_ZMAP_INFO
# DEFINITION_SCHEMA._VT_ZMAP_STAT
# DEFINITION_SCHEMA._VT_SWAPSPACE
# DEFINITION_SCHEMA._VT_NZREV
# DEFINITION_SCHEMA._VT_DISK_ALLOC
# DEFINITION_SCHEMA._VT_DISK_PARTITION
# DEFINITION_SCHEMA._VT_PG_TIME_OFFSET
# DEFINITION_SCHEMA._VT_TICK_TIMEBASE
# DEFINITION_SCHEMA._VT_SEQUENCE
# DEFINITION_SCHEMA._VT_FCOMM_BCAST
# DEFINITION_SCHEMA._VT_FCOMM_HOST_DIST
# DEFINITION_SCHEMA._VT_FCOMM_SPU_RESP
# DEFINITION_SCHEMA._VT_FCOMM_LOG
# DEFINITION_SCHEMA._VT_FCOMM_BCAST_TOPO
# DEFINITION_SCHEMA._VT_FCOMM_FUNNEL_TOPO
# DEFINITION_SCHEMA._VT_FCOMM_SPU2SPU_TOPO
# DEFINITION_SCHEMA._VT_FCOMM_SPU2SPU
# DEFINITION_SCHEMA._VT_FCOMM_SETTING
# DEFINITION_SCHEMA._VT_FCOMM_EXCEPTION
# DEFINITION_SCHEMA._VT_FCOMM_STAT
# DEFINITION_SCHEMA._VT_FCOMM_NODE_STAT
# DEFINITION_SCHEMA._VT_FCOMM_CALL_STAT
# DEFINITION_SCHEMA._VT_RESERVED
# DEFINITION_SCHEMA._VT_OBJCACHESTAT
# DEFINITION_SCHEMA._VT_ROLLBACK_STATUS
# DEFINITION_SCHEMA._VT_ROLLBACK_HISTORY
# DEFINITION_SCHEMA._VT_ROLLBACK_COST_ESTIMATE
# DEFINITION_SCHEMA._VT_TXUNFINISHED
# DEFINITION_SCHEMA._VT_TXJOURNAL
# DEFINITION_SCHEMA._VT_TXJOURNAL_DETAIL
# DEFINITION_SCHEMA._VT_TXJOPERATION
# DEFINITION_SCHEMA._VT_HOSTTXSTATE
# DEFINITION_SCHEMA._VT_SPUTXSTATE
# DEFINITION_SCHEMA._VT_HOSTTXMGR
# DEFINITION_SCHEMA._VT_SPUTXMGR
# DEFINITION_SCHEMA._VT_HOSTTX
# DEFINITION_SCHEMA._VT_SPUTX
# DEFINITION_SCHEMA._VT_HOSTTX_TBL_UPDATE
# DEFINITION_SCHEMA._VT_SPUTX_TBL_UPDATE
# DEFINITION_SCHEMA._VT_HOSTTX_TBL_READ
# DEFINITION_SCHEMA._VT_SPUTX_TBL_READ
# DEFINITION_SCHEMA._VT_HOSTTX_SERIALIZE
# DEFINITION_SCHEMA._VT_HOSTTX_QUEUE
# DEFINITION_SCHEMA._VT_HOSTTX_INVISIBLE
# DEFINITION_SCHEMA._VT_SPU_HARDWARE_ERROR
# DEFINITION_SCHEMA._VT_DEFAULTCERRORTEXT
# DEFINITION_SCHEMA._VT_IOSTAT
# DEFINITION_SCHEMA._VT_GROOM_STEP
# DEFINITION_SCHEMA._VT_SPU_METADATA_TX
# DEFINITION_SCHEMA._VT_TRANSTBL_IOSTAT
# DEFINITION_SCHEMA._VT_TRANSTBL_CONTEXT
# DEFINITION_SCHEMA._VT_TRANSTBL_NAME
# DEFINITION_SCHEMA._VT_CTA_PAGE
# DEFINITION_SCHEMA._VT_CTA_COLUMN
# DEFINITION_SCHEMA._VT_CTA_ADAPT
# DEFINITION_SCHEMA._VT_ZMAP_EVENT
# DEFINITION_SCHEMA._VT_ZMAP_FLUSH_DETAIL
# DEFINITION_SCHEMA._VT_ZMAP_SCAN_DETAIL
# DEFINITION_SCHEMA._VT_ZMAP_COMPLETION
# DEFINITION_SCHEMA._VT_COLUMN_TYPE
# DEFINITION_SCHEMA._VT_ZMAP_RESTRICT_OP
# DEFINITION_SCHEMA._VT_ZMAP_INDEX
# DEFINITION_SCHEMA._VT_HASH_JOIN_TEMP_TABLE
# DEFINITION_SCHEMA._VT_FPGA_SETUP_BASIC
# DEFINITION_SCHEMA._VT_FPGA_TBL_DESC
# DEFINITION_SCHEMA._VT_FPGA_INST_DESC
# DEFINITION_SCHEMA._VT_FPGA_INST
# DEFINITION_SCHEMA._VT_FPGA_VIS
# DEFINITION_SCHEMA._VT_EMULATOR
# DEFINITION_SCHEMA._VT_DEVCHECK_STATUS
# DEFINITION_SCHEMA._VT_DEVCHECK_ERRORS
# DEFINITION_SCHEMA._VT_PLAN_FILE
# DEFINITION_SCHEMA._VT_SCHED_RULE_ACTIVATION
# DEFINITION_SCHEMA._VT_SRC_LOG
# DEFINITION_SCHEMA._VT_SRC
# DEFINITION_SCHEMA._VT_SRC_TRANSIENT
# DEFINITION_SCHEMA._VT_SRC_DETAIL
# DEFINITION_SCHEMA._VT_SRCM_HASH
# DEFINITION_SCHEMA._VT_SRCM_INFO
# DEFINITION_SCHEMA._VT_SRCM_BASES
# DEFINITION_SCHEMA._VT_SRC_POLICY
# DEFINITION_SCHEMA._VT_JOB_PLAN
# DEFINITION_SCHEMA._VT_JOB_EVENT_TYPE
# DEFINITION_SCHEMA._VT_JOB_EVENT
# DEFINITION_SCHEMA._VT_FCOMM_CHANNEL_BUFFER_STAT
# DEFINITION_SCHEMA._VT_LP15_REPAIR_STATUS
# DEFINITION_SCHEMA._VT_LOAD_STATUS
# DEFINITION_SCHEMA._VT_SNIPPET_RESOURCE
# DEFINITION_SCHEMA._VT_SCHED_MISFIT_ID
# DEFINITION_SCHEMA._VT_PLAN_PROGRESS
# DEFINITION_SCHEMA._VT_SNIPPET_PROGRESS
# DEFINITION_SCHEMA._VT_FIXED_RESOURCE
# DEFINITION_SCHEMA._VT_FIXED_RESOURCE_ID
# DEFINITION_SCHEMA._VT_OBJFSCACHESTAT
# DEFINITION_SCHEMA._VT_OBJFSCACHEENTRYSTAT
# DEFINITION_SCHEMA._T_TOAST_5150
# DEFINITION_SCHEMA._T_TOAST_1215
# DEFINITION_SCHEMA._T_TOAST_5104
# DEFINITION_SCHEMA._T_TOAST_1255
# DEFINITION_SCHEMA._T_TOAST_1216
# DEFINITION_SCHEMA._T_TOAST_5114
# DEFINITION_SCHEMA._T_TOAST_5166
# DEMOUSER_CE.DIM_TIME
# DEMOUSER_CE.DIM_ACCOUNT
# DEMOUSER_CE.DIM_STOCK
# DEMOUSER_CE.DIM_EXCHANGE
# DEMOUSER_CE.DIM_DATE
# DEMOUSER_CE.FACT_TRANSACTIONS
# EQUITY_TRANSACTIONS.DIM_ACCOUNT
# EQUITY_TRANSACTIONS.DIM_STOCK
# EQUITY_TRANSACTIONS.DIM_EXCHANGE
# EQUITY_TRANSACTIONS.DIM_DATE
# EQUITY_TRANSACTIONS.FACT_TRANSACTIONS

# %% [markdown]
# ### Create tables based on DDL

# %%
tables_ddl = {
'dim_account':
f'''
DROP TABLE {schema_name}.dim_account IF EXISTS ;
CREATE TABLE {schema_name}.dim_account (
    account_id INT PRIMARY KEY,  
    account_type VARCHAR(50),
    status VARCHAR(20),
    opening_date DATE,
    risk_level VARCHAR(10),
    balance DECIMAL(18,2),
    margin_enabled BOOLEAN,
    trading_experience VARCHAR(20)
);
''',
'dim_stock':
f'''
-- Stock Dimension
DROP TABLE {schema_name}.dim_stock IF EXISTS;
CREATE TABLE {schema_name}.dim_stock (
    stock_id INT PRIMARY KEY,
    stock_symbol VARCHAR(10) UNIQUE,                  
    stock_name VARCHAR(255),
    sector VARCHAR(100),
    industry VARCHAR(100),
    market_cap DECIMAL(18,2)  
);
''',
'dim_exchange':
f'''
-- Exchange Dimension
DROP TABLE {schema_name}.dim_exchange IF EXISTS;
CREATE TABLE {schema_name}.dim_exchange (
    exchange_id INT PRIMARY KEY,
    exchange_name VARCHAR(100) UNIQUE,
    country VARCHAR(50),
    timezone VARCHAR(10),
    currency VARCHAR(10)
);
''',
'dim_date':
f'''
-- Time Dimension
DROP TABLE {schema_name}.dim_date IF EXISTS;
CREATE TABLE {schema_name}.dim_date (
    date_id INT PRIMARY KEY,
    transaction_date DATE,
    year INT,
    quarter INT,
    month INT,
    week INT,
    day_of_week INT,
    is_weekend BOOLEAN
);
''',
'fact_transactions':
f'''
-- Fact Transactions
DROP TABLE {schema_name}.fact_transactions IF EXISTS;
CREATE TABLE {schema_name}.fact_transactions (
    transaction_id INT PRIMARY KEY,
    account_id INT REFERENCES dim_account(account_id),
    stock_id INT REFERENCES dim_stock(stock_id),
    date_id INT REFERENCES dim_date(date_id),
    exchange_id INT REFERENCES dim_exchange(exchange_id),
    order_type VARCHAR(10) CHECK (transaction_type IN ("BUY", "SELL")),
    quantity INT CHECK (shares > 0),
    price DECIMAL(10,2) CHECK (price > 0),
    total_value DECIMAL(18,2)
);'''
}

# %%
for t_n, ddl in tables_ddl.items():
    print(f'Creating {schema_name}.{t_n}')
    try:
        cursor.execute(ddl)
        print(f'Created {schema_name}.{t_n}')
    except Exception as e:
        print(f"Error creating table: {e}")
# Out:
# Creating EQUITY_TRANSACTIONS.dim_account
# Created EQUITY_TRANSACTIONS.dim_account
# Creating EQUITY_TRANSACTIONS.dim_stock
# Created EQUITY_TRANSACTIONS.dim_stock
# Creating EQUITY_TRANSACTIONS.dim_exchange
# Created EQUITY_TRANSACTIONS.dim_exchange
# Creating EQUITY_TRANSACTIONS.dim_date
# Created EQUITY_TRANSACTIONS.dim_date
# Creating EQUITY_TRANSACTIONS.fact_transactions
# Created EQUITY_TRANSACTIONS.fact_transactions

# %% [markdown]
# ### Insert data from local files

# %%
 # load data from local folder
for table_name in generated_dfs_dict:
    print(f"Processing {table_name}")
    # load data from local folder
    cursor.execute(f'''
    insert into {schema_name}.{table_name} 
        select * from external '{dir_nz}/{table_name}.csv'
        using (
            LogDir '{dir_logs}'
            remotesource 'python'
            dateDelim '-'
            delim '|'
            skiprows 1
        )
                ''')
    print(f"{cursor.rowcount} Rows loaded into the {table_name.upper()}")
# Out:
# Processing dim_date
# 2282 Rows loaded into the DIM_DATE
# Processing dim_account
# 246301 Rows loaded into the DIM_ACCOUNT
# Processing dim_exchange
# 4 Rows loaded into the DIM_EXCHANGE
# Processing dim_stock
# 104 Rows loaded into the DIM_STOCK
# Processing fact_transactions
# 1200000 Rows loaded into the FACT_TRANSACTIONS

# %% [markdown]
# ## Close connection and clear logs

# %%
# Close the connection
if conn:
    conn.close()

# %% [markdown]
# ### Clear logs

# %%
import shutil

def clear_folder(folder_path):
    # Loop through all files in the folder
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        
        try:
            if os.path.isfile(file_path):  # Check if it's a file
                os.remove(file_path)  # Remove file
            elif os.path.isdir(file_path):  # If it's a directory, you can also remove it recursively
                shutil.rmtree(file_path)  # Remove the directory and its contents
        except Exception as e:
            print(f"Error deleting {file_path}: {e}")

# Example usage
folder_path = "./logs"
clear_folder(folder_path)
